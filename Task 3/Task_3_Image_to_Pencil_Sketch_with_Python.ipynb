# %% [markdown]
# # **LetsGrowMore- Virtual Internship Program (VIP)- Data Science**

# %% [markdown]
# **Author : Nithya Sri Santhoshini K V N S**

# %% [markdown]
# **Beginner Level**
#
# **Task 3 :- Image to Pencil Sketch with Python**

# %% [markdown]
# **Import required libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Importing Image**

# %%
image = cv2.imread("/content/picture.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=730x490 at 0x7FD560BB5350>

# %% [markdown]
# **Converting the original image to greyscale**

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=730x490 at 0x7FD560B4BA50>

# %% [markdown]
# **Inverting the greyscale image**

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=730x490 at 0x7FD560B575D0>

# %% [markdown]
# **Blurring the image by using the Gaussian Function in OpenCV**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=730x490 at 0x7FD560B4BE50>

# %% [markdown]
# **Pencil Sketch**

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=730x490 at 0x7FD560BB5150>

# %% [markdown]
# **Original Image and Pencil Sketch**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=730x490 at 0x7FD56D896090>
# <PIL.Image.Image image mode=L size=730x490 at 0x7FD56D0403D0>
